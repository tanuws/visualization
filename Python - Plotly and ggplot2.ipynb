# %% [markdown]
# # This a notebook that displays Plotly and ggplot2 visualizations

# %% [markdown]
# # Plotly (Python)

# %%
# Being by setting up a Plotly account (copy link below)
# Then copy the username and api_key to replace the current username and api_key 
# https://plot.ly/settings/api#/
import plotly
plotly.tools.set_credentials_file(username= 'tanuws', api_key = 'hKG1y6hAxdwvprBR2nAu')

# See the version of plotly used
plotly.__version__
# Out:
# '3.7.1'

# %% [markdown]
# ### Imports for Plotly

# %%
import plotly.figure_factory as ff
import plotly.plotly as py
import pandas as pd
import numpy as np 

# the base of rpy2 plotting is matplotlib, which is why we need to declare
# it inline in order to see the plots in the notebook
# %matplotlib inline

# %% [markdown]
# ### For context and explanations of the data:
# #### https://www.kaggle.com/ruslankl/mice-protein-expression/downloads/mice-protein-expression.zip/1

# %%
data = pd.read_csv('Data_Cortex_Nuclear.csv', sep=",")
# Just to see a snippet of what the data looks like
# checkData = data.iloc[0:5, 0:5]

# Col names to create categories of: MouseID, Genotype, Treatment, Behavior, class
# Uncomment below to get column names
# for col in data.columns: 
#     print(col) 
    
dataNoProtein = data[['MouseID', 'Genotype', 'Treatment', 'Behavior', 'class']] 
dataProtein = data.iloc[0:78,]

# This is a sample of the protein 
dataSampleProtein = dataProtein.sample(5, axis=1)

### For large datasets, it is not recommended to uses tables in plotly 
### because they are not able to hold many columns without overlapping
table = ff.create_table(dataSampleProtein)
py.iplot(table, filename='Mice Protein Expression Data')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tanuws/14.embed" height="2420px" width="100%"></iframe>

# %% [markdown]
# # Pivot table
# ## This is a Javascript Pivot Table
# ### (Not Plotly related but found it and thought it was interesting and incredibly interactive)

# %%
# Credit: https://github.com/nicolaskruchten/jupyter_pivottablejs 
from pivottablejs import pivot_ui
pivot_ui(data)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Breaking up the data

# %% [markdown]
# ### Control vs Trisonomy

# %%
dataControl = data.iloc[0:570,]
dataControl

dataTrisonomy = data.iloc[570:1080,]
dataTrisonomy
# Out:
#        MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N  \
# 570     3414_1  0.838053  1.006324  0.364953  2.603061  4.207680  0.202548
# 571     3414_2  0.938245  1.077099  0.366149  2.703612  4.484228  0.197465
# 572     3414_3  0.956488  1.108441  0.384049  2.662564  4.606357  0.203799
# 573     3414_4  0.731738  0.944241  0.324365  2.320243  3.621250  0.198649
# 574     3414_5  0.815503  1.005562  0.335976  2.379290  3.641657  0.217870
# 575     3414_6  0.807475  0.925253  0.334827  2.327989  4.018038  0.206437
# 576     3414_7  0.668978  0.903673  0.312435  2.291341  3.594778  0.207110
# 577     3414_8  0.776663  0.916962  0.327057  2.407933  3.627103  0.209446
# 578     3414_9  0.646086  0.942658  0.313107  2.259709  3.694630  0.217536
# 579    3414_10  0.602820  0.835561  0.301044  2.133126  3.064457  0.215345
# 580    3414_11  0.625976  0.806894  0.327938  2.217863  3.521615  0.236526
# ...

# %% [markdown]
# ### Classes

# %%
datacCSm = data[data['class'] == 'c-CS-m']
datacCSm

datacCSs = data[data['class'] == 'c-CS-s']
datacCSs

datacSCm = data[data['class'] == 'c-SC-m']
datacSCm

datacSCs = data[data['class'] == 'c-SC-s']
datacSCs

datatCSm = data[data['class'] == 't-CS-m']
datatCSm

datatCSs = data[data['class'] == 't-CS-s']
datatCSs

datatSCm = data[data['class'] == 't-SC-m']
datatSCm

datatSCs = data[data['class'] == 't-SC-s']
datatSCs
# Out:
#        MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N  \
# 945     3421_1  0.300101  0.584518  0.323672  2.028066  3.253325  0.215078
# 946     3421_2  0.296766  0.586306  0.317243  2.011118  3.233763  0.215232
# 947     3421_3  0.318266  0.613151  0.345641  2.153044  3.378373  0.220555
# 948     3421_4  0.286238  0.519021  0.300679  1.817545  2.763013  0.207565
# 949     3421_5  0.278369  0.503529  0.301781  1.913745  2.786042  0.208581
# 950     3421_6  0.298558  0.541521  0.310188  1.924401  2.976739  0.221331
# 951     3421_7  0.237557  0.420934  0.250060  1.501548  2.163610  0.187068
# 952     3421_8  0.252390  0.460967  0.258630  1.714286  2.420074  0.202469
# 953     3421_9  0.263753  0.489605  0.277330  1.781643  2.626361  0.215528
# 954    3421_10  0.238836  0.384145  0.234618  1.440000  1.928436  0.198691
# 955    3421_11  0.226900  0.395432  0.248694  1.460666  1.860128  0.188536
# ...

# %% [markdown]
# ### Set of all the scatter plots for numeric columns

# %% [markdown]
# ### Scatter Plot and Histogram Matrix

# %%
#Imports for the scatter matrix
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot  
init_notebook_mode(connected=True)  
import cufflinks as cf  
cf.go_offline() 
import seaborn as sns
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
## Caution it cannot be used for very large data sets as it will not be able to display the matrices. 
dataSampleProtein.scatter_matrix()
# Out:
# <div id="2f7de8e2-3d47-439c-8d0b-1839ba88e9eb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("2f7de8e2-3d47-439c-8d0b-1839ba88e9eb")) {
# ...

# %% [markdown]
# ### Scatter Plot

# %%
# Shows the correlations between the 5 samples of proteins

fig = ff.create_scatterplotmatrix(dataSampleProtein, height=800, width=800)
py.iplot(fig, filename='Protein Data')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tanuws/16.embed" height="800px" width="800px"></iframe>

# %% [markdown]
# ### Heatmap

# %%
dataSampleProtein.corr().iplot(kind='heatmap',colorscale="Blues",title="Feature Correlation Matrix")
# Out:
# <div id="608c3653-99b2-46ab-8a17-e0846aa5e809" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("608c3653-99b2-46ab-8a17-e0846aa5e809")) {
# ...

# %% [markdown]
# # ggplot2 (rpy2)

# %% [markdown]
# ##### The imports and code below was my original attempt to getting ggplot2 to function. The imports and code works for a local computer but was not able to display on Binder.

# %%
# import warnings
# warnings.filterwarnings('ignore')

# # Imports for rpy2
# import rpy2
# import rpy2.robjects as robjects
# import rpy2.robjects.numpy2ri
# rpy2.robjects.numpy2ri.activate() ## this allows numpy objects in python to be converted into R data
# from rpy2.robjects.packages import importr ##here we are able to import packages; before we imported functions. 
# from rpy2.robjects import Formula
# from rpy2.robjects import Environment
# from rpy2.robjects.vectors import IntVector, FloatVector
# from rpy2.robjects.lib import grid
# from rpy2.robjects.packages import data

# ## if we want to use the R visualizations, we need to convert a pandas DF to an R DF
# from rpy2.robjects import r, pandas2ri 
# pandas2ri.activate()
# from rpy2.robjects import Formula
# import rpy2.robjects.lib.ggplot2 as ggplot2

# %%
# load the needed extension for the %%R cell magic
# %load_ext rpy2.ipython

# %%
# %%R

# # load the ggplot2 library
# library(ggplot2)

# The R 'print' function
# rprint = robjects.globalenv.get("print")
# stats = importr('stats')
# grdevices = importr('grDevices')
# base = importr('base')
# datasets = importr('datasets')

# grid.activate()

# # Imports specifically for ggplot2
# import math, datetime
# import rpy2.robjects.lib.ggplot2 as ggplot2
# import rpy2.robjects as ro
# from rpy2.robjects.packages import importr
# base = importr('base')

# mtcars = data(datasets).fetch('mtcars')['mtcars']

# pp = ggplot2.ggplot(mtcars) + \
#      ggplot2.aes_string(x='wt', y='mpg', col='factor(cyl)') + \
#      ggplot2.geom_point() + \
#      ggplot2.geom_smooth(ggplot2.aes_string(group = 'cyl'),
#                          method = 'lm')
# pp.plot()

# %% [markdown]
# ### These imports and code works both on the local computer and on Binder.
# ### On the local computer the ggplot2 image displayed on a separate screen. This was an issue because Binder would not be able to display the visual at all
# ### The code below works in the local computer and on Binder to display the image inside the Notebook

# %%
import rpy2.robjects as ro
import math, datetime
import rpy2.robjects.lib.ggplot2 as ggplot2
import rpy2.robjects as ro
from rpy2.robjects.packages import importr, data

base = importr('base')
datasets = importr('datasets')
mtcars = data(datasets).fetch('mtcars')['mtcars']
mtcars
# Out:
# R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x1232b8748 / R:0x7fe92b5f30c8>
# [FloatVector, FloatVector, FloatVector, FloatVector, ..., FloatVector, FloatVector, FloatVector, FloatVector]
#   mpg: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x1232b86c8 / R:0x7fe9285f1540>
# [21.000000, 21.000000, 22.800000, 21.400000, ..., 15.800000, 19.700000, 15.000000, 21.400000]
#   cyl: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x1232b8908 / R:0x7fe9285eea10>
# [6.000000, 6.000000, 4.000000, 6.000000, ..., 8.000000, 6.000000, 8.000000, 4.000000]
#   disp: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x1232b8f48 / R:0x7fe92c086760>
# [160.000000, 160.000000, 108.000000, 258.000000, ..., 351.000000, 145.000000, 301.000000, 121.000000]
# ...

# %%
# credits: https://stackoverflow.com/questions/15060838/using-rpy2-with-ipython-notebooks

import uuid
from rpy2.robjects.packages import importr
from IPython.core.display import Image

grdevices = importr('grDevices')
def ggplot_notebook(gg, width = 800, height = 600, name = None):
    fn = name or '{uuid}.png'.format(uuid = uuid.uuid4())
    grdevices.png(fn, width = width, height = height)
    gg.plot()
    grdevices.dev_off()
    return Image(filename=fn)

# %%
pp = ggplot2.ggplot(mtcars) + \
     ggplot2.aes_string(x='wt', y='mpg', col='factor(cyl)') + \
     ggplot2.geom_point() + \
     ggplot2.geom_smooth(ggplot2.aes_string(group = 'cyl'), method = 'lm')
ggplot_notebook(pp, name = "rpy2_cars.png")
